# %%
from remote_sensing_core.ben_ge_s.ben_ge_s_dataset import BenGeS

# %%
config = {
    "root_dir_s1": "/Users/alexanderlontke/Documents/Uni/St. Gallen/SS_23/master_thesis/data/ben-ge-s/sentinel-1/s1_npy",
    "root_dir_s2": "/Users/alexanderlontke/Documents/Uni/St. Gallen/SS_23/master_thesis/data/ben-ge-s/sentinel-2/s2_npy",
    "root_dir_world_cover": "/Users/alexanderlontke/Documents/Uni/St. Gallen/SS_23/master_thesis/data/ben-ge-s/esaworldcover",
    "era5_data_path": "/Users/alexanderlontke/Documents/Uni/St. Gallen/SS_23/master_thesis/data/ben-ge-s/ben-ge-s_era-5.csv",
    "esa_world_cover_index_path": "/Users/alexanderlontke/Documents/Uni/St. Gallen/SS_23/master_thesis/data/ben-ge-s/sentinel-2/s2_npy/ben-ge-s_esaworldcover.csv",
    "sentinel_1_2_metadata_path": "/Users/alexanderlontke/Documents/Uni/St. Gallen/SS_23/master_thesis/data/ben-ge-s/ben-ge-s_sentinel12_meta.csv",
    "s2_bands": "ALL",
}

# %%
dataset = BenGeS(**config)

# %%
dataset[5]
# Out:
# {'s1_img': array([[[-0.00294656, -0.00264194, -0.00223264, ..., -0.00179675,
#           -0.0017422 , -0.00176247],
#          [-0.0029674 , -0.00274744, -0.00252246, ..., -0.00154937,
#           -0.00160198, -0.00167102],
#          [-0.00278432, -0.00273279, -0.00264311, ..., -0.00151191,
#           -0.00157062, -0.0015759 ],
#          ...,
#          [-0.00312042, -0.00314691, -0.00313367, ..., -0.00158382,
#           -0.00161722, -0.00178373],
#          [-0.00313411, -0.00307737, -0.00285359, ..., -0.00175767,
#           -0.00180592, -0.00192932],
#          [-0.00263235, -0.00275393, -0.00276653, ..., -0.00192266,
#           -0.00207148, -0.00221829]],
#
#         [[-0.00178871, -0.00153175, -0.00116113, ..., -0.00114162,
#           -0.00110048, -0.00104197],
#          [-0.00186387, -0.00173765, -0.00145982, ..., -0.00102158,
#           -0.00098917, -0.00093222],
#          [-0.00191755, -0.00189672, -0.00179431, ..., -0.00103508,
# ...

# %%
# Out:
# 11
